# %% [markdown]
# <a href="https://colab.research.google.com/github/HABIBI-001-10/ML-/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error,root_mean_squared_error

# %%
df=pd.read_csv("/content/Salary_Data.csv")
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
df.shape
# Out:
# (30, 2)

# %%
df.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df[['YearsExperience']]
y=df[['Salary']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (24, 1)
# (6, 1)
# (24, 1)
# (6, 1)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
print(y_pred)
# Out:
# [[115790.21011287]
#  [ 71498.27809463]
#  [102596.86866063]
#  [ 75267.80422384]
#  [ 55477.79204548]
#  [ 60189.69970699]]

# %%
print(y_test)
# Out:
#     Salary
# 27  112635
# 15   67938
# 23  113812
# 17   83088
# 8    64445
# 9    57189

# %% [markdown]
# **matrices used to evaluate linear regression**

# %%
mae=mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 6286.453830757749

# %%
rmse=root_mean_squared_error(y_test,y_pred)
print(rmse)
# Out:
# 7059.04362190151

# %%
mse=mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 49830096.85590839

# %%
r2score=r2_score(y_test,y_pred)
print(r2score)
# Out:
# 0.9024461774180497

# %%
plt.scatter(y_test,y_pred)
plt.plot(y_test,y_test,color='red')
plt.xlabel('actual salary')
plt.ylabel('predicted salary')
plt.title('act sal vs pred sal')
plt.show()

# %%
#live prediction
experience=float(input("enter a experiance: "))
data=[[experience]]
predicted_salary=model.predict(data)
print(predicted_salary)
# Out:
# enter a experiance: 9
# [[110135.92091906]]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
